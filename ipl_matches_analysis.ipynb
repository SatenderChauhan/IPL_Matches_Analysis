# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("matches.csv")

# %%
df.head()
# Out:
#    id Season   sss       city        date                        team1  \
# 0   1    IPL  2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    IPL  2017       Pune  06-04-2017               Mumbai Indians
# 2   3    IPL  2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    IPL  2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    IPL  2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
x=pd.concat([df["umpire1"],df["umpire2"]]).value_counts().sort_values(ascending=True)

# %%
x
# Out:
# Nand Kishore         1
# Sundaram Ravi        1
# Subroto Das          1
# SD Ranade            2
# K Bharatan           3
#                   ...
# SJA Taufel          55
# AK Chaudhary        58
# C Shamshuddin       73
# HDPK Dharmasena     87
# S Ravi             106
# Length: 75, dtype: int64

# %%
df.isnull()
# Out:
#         id  Season    sss   city   date  team1  team2  toss_winner  \
# 0    False   False  False  False  False  False  False        False
# 1    False   False  False  False  False  False  False        False
# 2    False   False  False  False  False  False  False        False
# 3    False   False  False  False  False  False  False        False
# 4    False   False  False  False  False  False  False        False
# ..     ...     ...    ...    ...    ...    ...    ...          ...
# 751  False   False  False  False  False  False  False        False
# 752  False   False  False  False  False  False  False        False
# 753  False   False  False  False  False  False  False        False
# 754  False   False  False  False  False  False  False        False
# 755  False   False  False  False  False  False  False        False
#
#      toss_decision  result  dl_applied  winner  win_by_runs  win_by_wickets  \
# 0            False   False       False   False        False           False
# ...

# %%
df.head()
# Out:
#    id Season   sss       city        date                        team1  \
# 0   1    IPL  2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    IPL  2017       Pune  06-04-2017               Mumbai Indians
# 2   3    IPL  2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    IPL  2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    IPL  2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
y=df["toss_decision"].value_counts()

# %%
y
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
y.index
# Out:
# Index(['field', 'bat'], dtype='object')

# %%
y.values
# Out:
# array([463, 293], dtype=int64)

# %%
plt.pie(y,labels=mylabels,startangle = 90,shadow=True)
mylabels=["field","bat"]
myexplode = [0.2, 0, 0, 0]
plt.legend()

# %%
x
# Out:
# Nand Kishore         1
# Sundaram Ravi        1
# Subroto Das          1
# SD Ranade            2
# K Bharatan           3
#                   ...
# SJA Taufel          55
# AK Chaudhary        58
# C Shamshuddin       73
# HDPK Dharmasena     87
# S Ravi             106
# Length: 75, dtype: int64

# %%
plt.bar(x.index,x.values,color="purple",width=0.8)
plt.xticks(rotation=90,fontsize=5)
plt.yticks(rotation=45)
plt.title("Umpire matches",color="red")
plt.xlabel("Name of umpire")
plt.ylabel("Count of matches")
# Out:
# Text(0, 0.5, 'Count of matches')

# %%
df.head()
# Out:
#    id Season   sss       city        date                        team1  \
# 0   1    IPL  2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    IPL  2017       Pune  06-04-2017               Mumbai Indians
# 2   3    IPL  2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    IPL  2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    IPL  2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
x=pd.concat([df["team1"],df["team2"]]).value_counts().sort_values(ascending=True)

# %%
x.index
# Out:
# Index(['Kochi Tuskers Kerala', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Gujarat Lions',
#        'Pune Warriors', 'Deccan Chargers', 'Sunrisers Hyderabad',
#        'Rajasthan Royals', 'Delhi Daredevils', 'Chennai Super Kings',
#        'Kings XI Punjab', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Mumbai Indians'],
#       dtype='object')

# %%
x.values
# Out:
# array([ 14,  14,  16,  16,  30,  46,  75, 108, 147, 161, 164, 176, 178,
#        180, 187], dtype=int64)

# %%
plt.scatter(x.index,x.values,color="red")
plt.xticks(rotation=90,fontsize=5)
plt.yticks(rotation=45)
plt.title("Total matches",color="purple")
plt.xlabel("Name of matches")
plt.ylabel("Name of team")
# Out:
# Text(0, 0.5, 'Name of team')

# %%
df.head()
# Out:
#    id Season   sss       city        date                        team1  \
# 0   1    IPL  2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    IPL  2017       Pune  06-04-2017               Mumbai Indians
# 2   3    IPL  2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    IPL  2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    IPL  2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ds=df.loc[(df["venue"]=="Wankhede Stadium")]
ws=ds[ds["win_by_runs"]>0]
slices=[len(ws),len(ds)-len(ws)]
lab=["batting 1","batting 2"]
plt.pie(slices,labels=lab,startangle=90,shadow=1,explode=(0,0.3),autopct="%0.3f%%",colors=["blue","red"])
# Out:
# ([<matplotlib.patches.Wedge at 0x15db2c37250>,
# ...
#  [Text(-1.0977088744946761, 0.0709593324068905, 'batting 1'),
#   Text(1.397084013628519, -0.09031200841321577, 'batting 2')],
#  [Text(-0.5987502951789142, 0.03870509040375845, '47.945%'),
#   Text(0.8981254373326191, -0.05805771969421012, '52.055%')])

# %%
ws=ds[ds["win_by_runs"]>0]

# %%
slices=[len(ws),len(ds)-len(ws)]

# %%
slices
# Out:
# [35, 38]

# %%
lab=["batting 1","batting 2"]

# %%
lab
# Out:
# ['batting 1', 'batting 2']

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("matches.csv")

# %%
df.head()
# Out:
#    id Season   sss       city        date                        team1  \
# 0   1    IPL  2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    IPL  2017       Pune  06-04-2017               Mumbai Indians
# 2   3    IPL  2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    IPL  2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    IPL  2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.loc[(df["city"]=="Rajkot")]
# Out:
#       id Season   sss    city        date                        team1  \
# 2      3    IPL  2017  Rajkot  07-04-2017                Gujarat Lions
# 12    13    IPL  2017  Rajkot  14-04-2017       Rising Pune Supergiant
# 19    20    IPL  2017  Rajkot  18-04-2017  Royal Challengers Bangalore
# 25    26    IPL  2017  Rajkot  23-04-2017              Kings XI Punjab
# 33    34    IPL  2017  Rajkot  29-04-2017                Gujarat Lions
# 581  582    IPL  2016  Rajkot  14-04-2016      Rising Pune Supergiants
# 590  591    IPL  2016  Rajkot  21-04-2016                Gujarat Lions
# 594  595    IPL  2016  Rajkot  24-04-2016  Royal Challengers Bangalore
# 603  604    IPL  2016  Rajkot  01-05-2016              Kings XI Punjab
# 606  607    IPL  2016  Rajkot  03-05-2016                Gujarat Lions
#
#                      team2                  toss_winner toss_decision  result  \
# 2    Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# ...

# %%
df.loc[(df["toss_decision"]=="bat")]
df.loc[(df["winner"]=="Kings XI Punjab")]
# Out:
#         id Season   sss        city        date                        team1  \
# 3        4    IPL  2017      Indore  08-04-2017       Rising Pune Supergiant
# 7        8    IPL  2017      Indore  10-04-2017  Royal Challengers Bangalore
# 25      26    IPL  2017      Rajkot  23-04-2017              Kings XI Punjab
# 34      35    IPL  2017  Chandigarh  30-04-2017             Delhi Daredevils
# 41      42    IPL  2017   Bangalore  05-05-2017              Kings XI Punjab
# ..     ...    ...   ...         ...         ...                          ...
# 704  11145    IPL  2019      Mohali  30-03-2019               Mumbai Indians
# 708  11149    IPL  2019      Mohali  01-04-2019              Kings XI Punjab
# 717  11313    IPL  2019      Mohali  08-04-2019          Sunrisers Hyderabad
# 727  11323    IPL  2019      Mohali  16-04-2019              Kings XI Punjab
# 750  11346    IPL  2019      Mohali  05-05-2019          Chennai Super Kings
#
# ...
